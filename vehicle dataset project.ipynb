# %% [markdown]
# # Project : vehicles Dataset

# %%
import pandas as pd
import numpy as num
import matplotlib as mt
import seaborn as sns
myData = pd.read_csv("C:\\Users\\ASUS\\Downloads\\archive\\vehicles.csv")

# %%
myData.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
myData.shape
# Out:
# (426880, 26)

# %%
myData.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# image_url           68
# description         70
# county          426880
# state                0
# lat               6549
# long              6549
# posting_date        68
# dtype: int64

# %%
for col in myData.columns:
    print( col,':', myData[col].nunique())
    print(myData[col].value_counts().nlargest(5))
    print('\n' + '*' * 20 + '\n')
# Out:
# id : 426880
# 7222695916    1
# 7313139418    1
# 7313423023    1
# 7313423324    1
# 7313424533    1
# Name: id, dtype: int64
#
# ********************
#
# url : 426880
# https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html            1
# https://nh.craigslist.org/cto/d/troy-1998-dodge-ram-59-cummins/7313139418.html             1
# https://nh.craigslist.org/ctd/d/north-hampton-2012-hyundai-sante-fe-se/7313423023.html     1
# https://nh.craigslist.org/ctd/d/derry-2008-chrysler-sebring-limited-all/7313423324.html    1
# https://nh.craigslist.org/ctd/d/derry-2002-toyota-camry-low-miles/7313424533.html          1
# Name: url, dtype: int64
#
# ********************
#
# region : 404
# columbus                   3608
# jacksonville               3562
# spokane / coeur d'alene    2988
# eugene                     2985
# fresno / madera            2983
# Name: region, dtype: int64
#
# ********************
#
# region_url : 413
# https://spokane.craigslist.org    2988
# ...

# %%
myData.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# ...

# %%
myData.duplicated().sum()
# Out:
# 0

# %%
myData.drop('county' , axis = 1)
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
for col in myData.columns:
    print( col,':', myData[col].nunique())
# Out:
# id : 426880
# url : 426880
# region : 404
# region_url : 413
# price : 15655
# year : 114
# manufacturer : 42
# model : 29667
# condition : 6
# cylinders : 8
# fuel : 5
# odometer : 104870
# title_status : 6
# transmission : 3
# VIN : 118264
# drive : 3
# size : 4
# type : 13
# paint_color : 12
# image_url : 241899
# description : 360911
# county : 0
# state : 51
# lat : 53181
# long : 53772
# posting_date : 381536

# %% [markdown]
# # What is the most frequent drive ?

# %%
myData['drive'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='drive'>

# %% [markdown]
# # What is the highest year of manufacture?

# %%
myData['year'].value_counts()
# Out:
# 2017.0    36420
# 2018.0    36369
# 2015.0    31538
# 2013.0    30794
# 2016.0    30434
#           ...
# 1943.0        1
# 1915.0        1
# 1902.0        1
# 1905.0        1
# 1909.0        1
# Name: year, Length: 114, dtype: int64

# %%
sns.distplot(myData['year'] , kde = True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# # What is the most frequent size of a vehicle?

# %%
myData['size'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='size'>

# %% [markdown]
# # which region have the highest number of sedan vehicles?

# %%
sns.countplot(y=myData['region'] , data =myData[myData['type']=='sedan'] ,order =myData['region'].value_counts().index[:5])
# Out:
# <AxesSubplot:xlabel='count', ylabel='region'>

# %% [markdown]
# # What is the most popular vehicle  model?

# %%
sns.countplot(y=myData['model'] , data =myData ,order =myData['model'].value_counts().index[:5])
# Out:
# <AxesSubplot:xlabel='count', ylabel='model'>

# %% [markdown]
# # vehicle condition per year

# %%
sns.lineplot(x='year' , y = 'condition' , data = myData)
# Out:
# <AxesSubplot:xlabel='year', ylabel='condition'>
